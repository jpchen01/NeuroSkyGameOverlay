# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 15]

# %%
data = pd.read_csv("./datalog.log")
data
# Out:
#               time        type  value
# 0     1.645686e+09   attention      0
# 1     1.645686e+09  meditation      0
# 2     1.645686e+09   attention      0
# 3     1.645686e+09  meditation      0
# 4     1.645686e+09   attention      0
# ...            ...         ...    ...
# 4553  1.645688e+09  meditation     60
# 4554  1.645688e+09   attention     60
# 4555  1.645688e+09  meditation     60
# 4556  1.645688e+09   attention      0
# 4557  1.645688e+09  meditation      0
#
# [4558 rows x 3 columns]

# %%
gb = data.groupby('type')
att, med = (gb.get_group(x) for x in gb.groups)

# %%
att = att.rename(columns={'value':'attention_val'})
att
# Out:
#               time       type  attention_val
# 0     1.645686e+09  attention              0
# 2     1.645686e+09  attention              0
# 4     1.645686e+09  attention              0
# 6     1.645686e+09  attention              0
# 8     1.645686e+09  attention              0
# ...            ...        ...            ...
# 4548  1.645688e+09  attention             60
# 4550  1.645688e+09  attention             60
# 4552  1.645688e+09  attention             60
# 4554  1.645688e+09  attention             60
# 4556  1.645688e+09  attention              0
#
# [2279 rows x 3 columns]

# %%
med = med.rename(columns={'value':'meditation_val'})

# %%
plt.plot(med['time'], med['meditation_val'])

# %%
med.describe()
# Out:
#                time  meditation_val
# count  2.279000e+03     2279.000000
# mean   1.645687e+09       53.954805
# std    6.580268e+02       16.332615
# min    1.645686e+09        0.000000
# 25%    1.645686e+09       43.000000
# 50%    1.645687e+09       54.000000
# 75%    1.645687e+09       64.000000
# max    1.645688e+09      100.000000

# %%
att.describe()
# Out:
#                time  attention_val
# count  2.279000e+03    2279.000000
# mean   1.645687e+09      44.826678
# std    6.580268e+02      18.612335
# min    1.645686e+09       0.000000
# 25%    1.645686e+09      30.000000
# 50%    1.645687e+09      44.000000
# 75%    1.645687e+09      57.000000
# max    1.645688e+09     100.000000

# %%
plt.plot(att['time'], att['attention_val'])
